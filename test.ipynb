# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
import csv
import os

# 指定文件夾路徑和CSV文件名稱
folder_path = "C:\\Users\\User\\Desktop\\賽馬"
csv_file_name = "2020-2023賽馬賽事.csv"

# 確保文件夾存在，如果不存在則創建它
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# 組合完整的CSV文件路徑
csv_file_path = os.path.join(folder_path, csv_file_name)

# 使用請求headers
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.3"}

def fetch_race_data(race_url, race_date):
    response_race = requests.get(race_url, headers=headers)


    if response_race.status_code != 200:
        print(f"無法獲取比賽信息，比賽URL: {race_url}")
        return []

    response_race.encoding = 'EUC-JP'
    soup_race = BeautifulSoup(response_race.text, 'html.parser')
    race_data_list = []

    race_info = soup_race.find("div", {"class": "mainrace_data fc"})
    if not race_info:
        print(f"無法獲取比賽信息，比賽URL: {race_url}")
        return []

    race_name = race_info.find("h1").text.strip()
    span_text = race_info.find("span").text.strip().replace("\xa0", " ").replace("/", "、")
    split_text = span_text.split("、")
    distance = split_text[0] if len(split_text) > 0 else ""
    weather = split_text[1] if len(split_text) > 1 else ""
    race_number = soup_race.find("dt").text.strip()



    race_place_links = soup_race.select("ul.race_place.fc a.active")
    race_place = race_place_links[0].text if race_place_links else ""

    race_table = soup_race.find("table", {"class": "race_table_01 nk_tb_common"})
    if race_table:
        rows = race_table.find_all("tr")
        for row in rows[1:]:
            cols = row.find_all("td")
            if len(cols) >= 21:
                race_data_list.append({
                    '賽事時間': race_date,
                    '地點': race_place,
                    '場名': race_name,
                    '場次': race_number,
                    '距離': distance,
                    '天氣': weather,
                    '名次': cols[0].text.strip(),
                    '馬名': cols[3].text.strip(),
                    '性別年紀': cols[4].text.strip(),
                    '馬重量': cols[14].text.strip(),
                    '騎手': cols[6].text.strip(),
                    '重量': cols[5].text.strip(),
                    '抵達時間': cols[7].text.strip(),
                    '單柱賠率': cols[12].text.strip(),
                    '獎金': cols[20].text.strip()
                })
    return race_data_list

with open(csv_file_path, mode='w', newline='', encoding='utf-8-sig') as csv_file:
    fieldnames = ['賽事時間', '地點', '場名', '場次', '距離', '天氣', '名次', '馬名', '性別年紀', '馬重量', '騎手', '重量', '抵達時間', '單柱賠率', '獎金']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    writer.writeheader()

    start_date = datetime(2020, 1, 1)
    end_date = datetime(2023, 10, 1)
    
    current_date = start_date
    while current_date <= end_date:
        formatted_date = current_date.strftime("%Y%m%d")
        date_url = f"https://db.netkeiba.com/race/list/{formatted_date}/"
        
        response_date = requests.get(date_url, headers=headers)
        if response_date.status_code != 200:
            print(f"無法獲取日期信息，日期URL: {date_url}")
            current_date += timedelta(days=1)
            continue

        soup_date = BeautifulSoup(response_date.text, 'html.parser')
        race_links = [a["href"] for a in soup_date.select(".race_top_data_info a") if "/movie/" not in a["href"]]


        if not race_links:
            print(f"{formatted_date} 沒有賽事。")
            current_date += timedelta(days=1)
            continue

        for race_link in race_links:
            race_data = fetch_race_data(f"https://db.netkeiba.com{race_link}", formatted_date)
            for item in race_data:
                writer.writerow(item)
        print(f"{formatted_date} 完成。")
        current_date += timedelta(days=1)
# Out:
# 20200101 沒有賽事。
# 20200102 沒有賽事。
# 20200103 沒有賽事。
# 20200104 沒有賽事。
# 20200105 完成。
# 20200106 完成。
# 20200107 沒有賽事。
# 20200108 沒有賽事。
# 20200109 沒有賽事。
# 20200110 沒有賽事。
# 20200111 完成。
# 20200112 完成。
# 20200113 完成。
# 20200114 沒有賽事。
# 20200115 沒有賽事。
# 20200116 沒有賽事。
# 20200117 沒有賽事。
# 20200118 完成。
# 20200119 完成。
# 20200120 沒有賽事。
# 20200121 沒有賽事。
# 20200122 沒有賽事。
# 20200123 沒有賽事。
# 20200124 沒有賽事。
# 20200125 完成。
# 20200126 完成。
# 20200127 沒有賽事。
# 20200128 沒有賽事。
# 20200129 沒有賽事。
# 20200130 沒有賽事。
# 20200131 沒有賽事。
# 20200201 完成。
# 20200202 完成。
# 20200203 沒有賽事。
# 20200204 沒有賽事。
# 20200205 沒有賽事。
# 20200206 沒有賽事。
# 20200207 沒有賽事。
# 20200208 完成。
# 20200209 完成。
# 20200210 沒有賽事。
# 20200211 沒有賽事。
# 20200212 沒有賽事。
# 20200213 沒有賽事。
# 20200214 沒有賽事。
# 20200215 完成。
# 20200216 完成。
# 20200217 沒有賽事。
# 20200218 沒有賽事。
# 20200219 沒有賽事。
# 20200220 沒有賽事。
# 20200221 沒有賽事。
# 20200222 完成。
# 20200223 完成。
# 20200224 沒有賽事。
# 20200225 沒有賽事。
# 20200226 沒有賽事。
# 20200227 沒有賽事。
# 20200228 沒有賽事。
# 20200229 完成。
# 20200301 完成。
# 20200302 沒有賽事。
# 20200303 沒有賽事。
# 20200304 沒有賽事。
# 20200305 沒有賽事。
# 20200306 沒有賽事。
# 20200307 完成。
# 20200308 完成。
# 20200309 沒有賽事。
# 20200310 沒有賽事。
# 20200311 沒有賽事。
# 20200312 沒有賽事。
# 20200313 沒有賽事。
# 20200314 完成。
# 20200315 完成。
# 20200316 沒有賽事。
# 20200317 沒有賽事。
# 20200318 沒有賽事。
# 20200319 沒有賽事。
# 20200320 完成。
# 20200321 完成。
# 20200322 完成。
# 20200323 沒有賽事。
# 20200324 沒有賽事。
# 20200325 沒有賽事。
# 20200326 沒有賽事。
# 20200327 沒有賽事。
# 20200328 完成。
# 20200329 完成。
# 20200330 沒有賽事。
# 20200331 完成。
# 20200401 沒有賽事。
# 20200402 沒有賽事。
# 20200403 沒有賽事。
# 20200404 完成。
# 20200405 完成。
# 20200406 沒有賽事。
# 20200407 沒有賽事。
# 20200408 沒有賽事。
# 20200409 沒有賽事。
# 20200410 沒有賽事。
# 20200411 完成。
# 20200412 完成。
# 20200413 沒有賽事。
# 20200414 沒有賽事。
# 20200415 沒有賽事。
# 20200416 沒有賽事。
# 20200417 沒有賽事。
# 20200418 完成。
# 20200419 完成。
# 20200420 沒有賽事。
# 20200421 沒有賽事。
# 20200422 沒有賽事。
# 20200423 沒有賽事。
# 20200424 沒有賽事。
# 20200425 完成。
# 20200426 完成。
# 20200427 沒有賽事。
# 20200428 沒有賽事。
# 20200429 沒有賽事。
# 20200430 沒有賽事。
# 20200501 沒有賽事。
# 20200502 完成。
# 20200503 完成。
# 20200504 沒有賽事。
# 20200505 沒有賽事。
# 20200506 沒有賽事。
# 20200507 沒有賽事。
# 20200508 沒有賽事。
# 20200509 完成。
# 20200510 完成。
# 20200511 沒有賽事。
# 20200512 沒有賽事。
# 20200513 沒有賽事。
# 20200514 沒有賽事。
# 20200515 沒有賽事。
# 20200516 完成。
# 20200517 完成。
# 20200518 沒有賽事。
# 20200519 沒有賽事。
# 20200520 沒有賽事。
# 20200521 沒有賽事。
# 20200522 沒有賽事。
# 20200523 完成。
# 20200524 完成。
# 20200525 沒有賽事。
# 20200526 沒有賽事。
# 20200527 沒有賽事。
# 20200528 沒有賽事。
# 20200529 沒有賽事。
# 20200530 完成。
# 20200531 完成。
# 20200601 沒有賽事。
# 20200602 沒有賽事。
# 20200603 沒有賽事。
# 20200604 沒有賽事。
# 20200605 沒有賽事。
# 20200606 完成。
# 20200607 完成。
# 20200608 沒有賽事。
# 20200609 沒有賽事。
# 20200610 沒有賽事。
# 20200611 沒有賽事。
# 20200612 沒有賽事。
# 20200613 完成。
# 20200614 完成。
# 20200615 沒有賽事。
# 20200616 沒有賽事。
# 20200617 沒有賽事。
# 20200618 沒有賽事。
# 20200619 沒有賽事。
# 20200620 完成。
# 20200621 完成。
# 20200622 沒有賽事。
# 20200623 沒有賽事。
# 20200624 沒有賽事。
# 20200625 沒有賽事。
# 20200626 沒有賽事。
# 20200627 完成。
# 20200628 完成。
# 20200629 沒有賽事。
# 20200630 沒有賽事。
# 20200701 沒有賽事。
# 20200702 沒有賽事。
# 20200703 沒有賽事。
# 20200704 完成。
# 20200705 完成。
# 20200706 沒有賽事。
# 20200707 沒有賽事。
# 20200708 沒有賽事。
# 20200709 沒有賽事。
# 20200710 沒有賽事。
# 20200711 完成。
# 20200712 完成。
# 20200713 沒有賽事。
# 20200714 沒有賽事。
# 20200715 沒有賽事。
# 20200716 沒有賽事。
# 20200717 沒有賽事。
# 20200718 完成。
# 20200719 完成。
# 20200720 沒有賽事。
# 20200721 沒有賽事。
# 20200722 沒有賽事。
# 20200723 沒有賽事。
# 20200724 沒有賽事。
# 20200725 完成。
# 20200726 完成。
# 20200727 沒有賽事。
# 20200728 沒有賽事。
# 20200729 沒有賽事。
# 20200730 沒有賽事。
# 20200731 沒有賽事。
# 20200801 完成。
# 20200802 完成。
# 20200803 沒有賽事。
# 20200804 沒有賽事。
# 20200805 沒有賽事。
# 20200806 沒有賽事。
# 20200807 沒有賽事。
# 20200808 完成。
# 20200809 完成。
# 20200810 沒有賽事。
# 20200811 沒有賽事。
# 20200812 沒有賽事。
# 20200813 沒有賽事。
# 20200814 沒有賽事。
# 20200815 完成。
# 20200816 完成。
# 20200817 沒有賽事。
# 20200818 沒有賽事。
# 20200819 沒有賽事。
# 20200820 沒有賽事。
# 20200821 沒有賽事。
# 20200822 完成。
# 20200823 完成。
# 20200824 沒有賽事。
# 20200825 沒有賽事。
# 20200826 沒有賽事。
# 20200827 沒有賽事。
# 20200828 沒有賽事。
# 20200829 完成。
# 20200830 完成。
# 20200831 沒有賽事。
# 20200901 沒有賽事。
# 20200902 沒有賽事。
# 20200903 沒有賽事。
# 20200904 沒有賽事。
# 20200905 完成。
# 20200906 完成。
# 20200907 沒有賽事。
# 20200908 沒有賽事。
# 20200909 沒有賽事。
# 20200910 沒有賽事。
# 20200911 沒有賽事。
# 20200912 完成。
# 20200913 完成。
# 20200914 沒有賽事。
# 20200915 沒有賽事。
# 20200916 沒有賽事。
# 20200917 沒有賽事。
# 20200918 沒有賽事。
# 20200919 完成。
# 20200920 完成。
# 20200921 完成。
# 20200922 沒有賽事。
# 20200923 沒有賽事。
# 20200924 沒有賽事。
# 20200925 沒有賽事。
# 20200926 完成。
# 20200927 完成。
# 20200928 沒有賽事。
# 20200929 沒有賽事。
# 20200930 沒有賽事。
# 20201001 沒有賽事。
# 20201002 沒有賽事。
# 20201003 完成。
# 20201004 完成。
# 20201005 沒有賽事。
# 20201006 沒有賽事。
# 20201007 沒有賽事。
# 20201008 沒有賽事。
# 20201009 沒有賽事。
# 20201010 完成。
# 20201011 完成。
# 20201012 沒有賽事。
# 20201013 沒有賽事。
# 20201014 沒有賽事。
# 20201015 沒有賽事。
# 20201016 沒有賽事。
# 20201017 完成。
# 20201018 完成。
# 20201019 沒有賽事。
# 20201020 沒有賽事。
# 20201021 沒有賽事。
# 20201022 沒有賽事。
# 20201023 沒有賽事。
# 20201024 完成。
# 20201025 完成。
# 20201026 沒有賽事。
# 20201027 沒有賽事。
# 20201028 沒有賽事。
# 20201029 沒有賽事。
# 20201030 沒有賽事。
# 20201031 完成。
# 20201101 完成。
# 20201102 沒有賽事。
# 20201103 沒有賽事。
# 20201104 沒有賽事。
# 20201105 沒有賽事。
# 20201106 沒有賽事。
# 20201107 完成。
# 20201108 完成。
# 20201109 沒有賽事。
# 20201110 沒有賽事。
# 20201111 沒有賽事。
# 20201112 沒有賽事。
# 20201113 沒有賽事。
# 20201114 完成。
# 20201115 完成。
# 20201116 沒有賽事。
# 20201117 沒有賽事。
# 20201118 沒有賽事。
# 20201119 沒有賽事。
# 20201120 沒有賽事。
# 20201121 完成。
# 20201122 完成。
# 20201123 完成。
# 20201124 沒有賽事。
# 20201125 沒有賽事。
# 20201126 沒有賽事。
# 20201127 沒有賽事。
# 20201128 完成。
# 20201129 完成。
# 20201130 沒有賽事。
# 20201201 沒有賽事。
# 20201202 沒有賽事。
# 20201203 沒有賽事。
# 20201204 沒有賽事。
# 20201205 完成。
# 20201206 完成。
# 20201207 沒有賽事。
# 20201208 沒有賽事。
# 20201209 沒有賽事。
# 20201210 沒有賽事。
# 20201211 沒有賽事。
# 20201212 完成。
# 20201213 完成。
# 20201214 沒有賽事。
# 20201215 沒有賽事。
# 20201216 沒有賽事。
# 20201217 沒有賽事。
# 20201218 沒有賽事。
# 20201219 完成。
# 20201220 完成。
# 20201221 沒有賽事。
# 20201222 沒有賽事。
# 20201223 沒有賽事。
# 20201224 沒有賽事。
# 20201225 沒有賽事。
# 20201226 完成。
# 20201227 完成。
# 20201228 沒有賽事。
# 20201229 沒有賽事。
# 20201230 沒有賽事。
# 20201231 沒有賽事。
# 20210101 沒有賽事。
# 20210102 沒有賽事。
# 20210103 沒有賽事。
# 20210104 沒有賽事。
# 20210105 完成。
# 20210106 沒有賽事。
# 20210107 沒有賽事。
# 20210108 沒有賽事。
# 20210109 完成。
# 20210110 完成。
# 20210111 完成。
# 20210112 沒有賽事。
# 20210113 沒有賽事。
# 20210114 沒有賽事。
# 20210115 沒有賽事。
# 20210116 完成。
# 20210117 完成。
# 20210118 沒有賽事。
# 20210119 沒有賽事。
# 20210120 沒有賽事。
# 20210121 沒有賽事。
# 20210122 沒有賽事。
# 20210123 完成。
# 20210124 完成。
# 20210125 沒有賽事。
# 20210126 沒有賽事。
# 20210127 沒有賽事。
# 20210128 沒有賽事。
# 20210129 沒有賽事。
# 20210130 完成。
# 20210131 完成。
# 20210201 沒有賽事。
# 20210202 沒有賽事。
# 20210203 沒有賽事。
# 20210204 沒有賽事。
# 20210205 沒有賽事。
# 20210206 完成。
# 20210207 完成。
# 20210208 沒有賽事。
# 20210209 沒有賽事。
# 20210210 沒有賽事。
# 20210211 沒有賽事。
# 20210212 沒有賽事。
# 20210213 完成。
# 20210214 完成。
# 20210215 沒有賽事。
# 20210216 沒有賽事。
# 20210217 沒有賽事。
# 20210218 沒有賽事。
# 20210219 沒有賽事。
# 20210220 完成。
# 20210221 完成。
# 20210222 沒有賽事。
# 20210223 沒有賽事。
# 20210224 沒有賽事。
# 20210225 沒有賽事。
# 20210226 沒有賽事。
# 20210227 完成。
# 20210228 完成。
# 20210301 沒有賽事。
# 20210302 沒有賽事。
# 20210303 沒有賽事。
# 20210304 沒有賽事。
# 20210305 沒有賽事。
# 20210306 完成。
# 20210307 完成。
# 20210308 沒有賽事。
# 20210309 沒有賽事。
# 20210310 沒有賽事。
# 20210311 沒有賽事。
# 20210312 沒有賽事。
# 20210313 完成。
# 20210314 完成。
# 20210315 沒有賽事。
# 20210316 沒有賽事。
# 20210317 沒有賽事。
# 20210318 沒有賽事。
# 20210319 沒有賽事。
# 20210320 完成。
# 20210321 完成。
# 20210322 沒有賽事。
# 20210323 沒有賽事。
# 20210324 沒有賽事。
# 20210325 沒有賽事。
# 20210326 沒有賽事。
# 20210327 完成。
# 20210328 完成。
# 20210329 沒有賽事。
# 20210330 沒有賽事。
# 20210331 沒有賽事。
# 20210401 沒有賽事。
# 20210402 沒有賽事。
# 20210403 完成。
# 20210404 完成。
# 20210405 沒有賽事。
# 20210406 沒有賽事。
# 20210407 沒有賽事。
# 20210408 沒有賽事。
# 20210409 沒有賽事。
# 20210410 完成。
# 20210411 完成。
# 20210412 沒有賽事。
# 20210413 沒有賽事。
# 20210414 沒有賽事。
# 20210415 沒有賽事。
# 20210416 沒有賽事。
# 20210417 完成。
# 20210418 完成。
# 20210419 沒有賽事。
# 20210420 沒有賽事。
# 20210421 沒有賽事。
# 20210422 沒有賽事。
# 20210423 沒有賽事。
# 20210424 完成。
# 20210425 完成。
# 20210426 沒有賽事。
# 20210427 沒有賽事。
# 20210428 沒有賽事。
# 20210429 沒有賽事。
# 20210430 沒有賽事。
# 20210501 完成。
# 20210502 完成。
# 20210503 沒有賽事。
# 20210504 沒有賽事。
# 20210505 沒有賽事。
# 20210506 沒有賽事。
# 20210507 沒有賽事。
# 20210508 完成。
# 20210509 完成。
# 20210510 沒有賽事。
# 20210511 沒有賽事。
# 20210512 沒有賽事。
# 20210513 沒有賽事。
# 20210514 沒有賽事。
# 20210515 完成。
# 20210516 完成。
# 20210517 沒有賽事。
# 20210518 沒有賽事。
# 20210519 沒有賽事。
# 20210520 沒有賽事。
# 20210521 沒有賽事。
# 20210522 完成。
# 20210523 完成。
# 20210524 沒有賽事。
# 20210525 沒有賽事。
# 20210526 沒有賽事。
# 20210527 沒有賽事。
# 20210528 沒有賽事。
# 20210529 完成。
# 20210530 完成。
# 20210531 沒有賽事。
# 20210601 沒有賽事。
# 20210602 沒有賽事。
# 20210603 沒有賽事。
# 20210604 沒有賽事。
# 20210605 完成。
# 20210606 完成。
# 20210607 沒有賽事。
# 20210608 沒有賽事。
# 20210609 沒有賽事。
# 20210610 沒有賽事。
# 20210611 沒有賽事。
# 20210612 完成。
# 20210613 完成。
# 20210614 沒有賽事。
# 20210615 沒有賽事。
# 20210616 沒有賽事。
# 20210617 沒有賽事。
# 20210618 沒有賽事。
# 20210619 完成。
# 20210620 完成。
# 20210621 沒有賽事。
# 20210622 沒有賽事。
# 20210623 沒有賽事。
# 20210624 沒有賽事。
# 20210625 沒有賽事。
# 20210626 完成。
# 20210627 完成。
# 20210628 沒有賽事。
# 20210629 沒有賽事。
# 20210630 沒有賽事。
# 20210701 沒有賽事。
# 20210702 沒有賽事。
# 20210703 完成。
# 20210704 完成。
# 20210705 沒有賽事。
# 20210706 沒有賽事。
# 20210707 沒有賽事。
# 20210708 沒有賽事。
# 20210709 沒有賽事。
# 20210710 完成。
# 20210711 完成。
# 20210712 沒有賽事。
# 20210713 沒有賽事。
# 20210714 沒有賽事。
# 20210715 沒有賽事。
# 20210716 沒有賽事。
# 20210717 完成。
# 20210718 完成。
# 20210719 沒有賽事。
# 20210720 沒有賽事。
# 20210721 沒有賽事。
# 20210722 沒有賽事。
# 20210723 沒有賽事。
# 20210724 完成。
# 20210725 完成。
# 20210726 沒有賽事。
# 20210727 沒有賽事。
# 20210728 沒有賽事。
# 20210729 沒有賽事。
# 20210730 沒有賽事。
# 20210731 完成。
# 20210801 完成。
# 20210802 沒有賽事。
# 20210803 沒有賽事。
# 20210804 沒有賽事。
# 20210805 沒有賽事。
# 20210806 沒有賽事。
# 20210807 完成。
# 20210808 完成。
# 20210809 沒有賽事。
# 20210810 沒有賽事。
# 20210811 沒有賽事。
# 20210812 沒有賽事。
# 20210813 沒有賽事。
# 20210814 完成。
# 20210815 完成。
# 20210816 沒有賽事。
# 20210817 沒有賽事。
# 20210818 沒有賽事。
# 20210819 沒有賽事。
# 20210820 沒有賽事。
# 20210821 完成。
# 20210822 完成。
# 20210823 沒有賽事。
# 20210824 沒有賽事。
# 20210825 沒有賽事。
# 20210826 沒有賽事。
# 20210827 沒有賽事。
# 20210828 完成。
# 20210829 完成。
# 20210830 沒有賽事。
# 20210831 沒有賽事。
# 20210901 沒有賽事。
# 20210902 沒有賽事。
# 20210903 沒有賽事。
# 20210904 完成。
# 20210905 完成。
# 20210906 沒有賽事。
# 20210907 沒有賽事。
# 20210908 沒有賽事。
# 20210909 沒有賽事。
# 20210910 沒有賽事。
# 20210911 完成。
# 20210912 完成。
# 20210913 沒有賽事。
# 20210914 沒有賽事。
# 20210915 沒有賽事。
# 20210916 沒有賽事。
# 20210917 沒有賽事。
# 20210918 完成。
# 20210919 完成。
# 20210920 完成。
# 20210921 沒有賽事。
# 20210922 沒有賽事。
# 20210923 沒有賽事。
# 20210924 沒有賽事。
# 20210925 完成。
# 20210926 完成。
# 20210927 沒有賽事。
# 20210928 沒有賽事。
# 20210929 沒有賽事。
# 20210930 沒有賽事。
# 20211001 沒有賽事。
# 20211002 完成。
# 20211003 完成。
# 20211004 沒有賽事。
# 20211005 沒有賽事。
# 20211006 沒有賽事。
# 20211007 沒有賽事。
# 20211008 沒有賽事。
# 20211009 完成。
# 20211010 完成。
# 20211011 沒有賽事。
# 20211012 沒有賽事。
# 20211013 沒有賽事。
# 20211014 沒有賽事。
# 20211015 沒有賽事。
# 20211016 完成。
# 20211017 完成。
# 20211018 沒有賽事。
# 20211019 沒有賽事。
# 20211020 沒有賽事。
# 20211021 沒有賽事。
# 20211022 沒有賽事。
# 20211023 完成。
# 20211024 完成。
# 20211025 沒有賽事。
# 20211026 沒有賽事。
# 20211027 沒有賽事。
# 20211028 沒有賽事。
# 20211029 沒有賽事。
# 20211030 完成。
# 20211031 完成。
# 20211101 沒有賽事。
# 20211102 沒有賽事。
# 20211103 沒有賽事。
# 20211104 沒有賽事。
# 20211105 沒有賽事。
# 20211106 完成。
# 20211107 完成。
# 20211108 沒有賽事。
# 20211109 沒有賽事。
# 20211110 沒有賽事。
# 20211111 沒有賽事。
# 20211112 沒有賽事。
# 20211113 完成。
# 20211114 完成。
# 20211115 沒有賽事。
# 20211116 沒有賽事。
# 20211117 沒有賽事。
# 20211118 沒有賽事。
# 20211119 沒有賽事。
# 20211120 完成。
# 20211121 完成。
# 20211122 沒有賽事。
# 20211123 沒有賽事。
# 20211124 沒有賽事。
# 20211125 沒有賽事。
# 20211126 沒有賽事。
# 20211127 完成。
# 20211128 完成。
# 20211129 沒有賽事。
# 20211130 沒有賽事。
# 20211201 沒有賽事。
# 20211202 沒有賽事。
# 20211203 沒有賽事。
# 20211204 完成。
# 20211205 完成。
# 20211206 沒有賽事。
# 20211207 沒有賽事。
# 20211208 沒有賽事。
# 20211209 沒有賽事。
# 20211210 沒有賽事。
# 20211211 完成。
# 20211212 完成。
# 20211213 沒有賽事。
# 20211214 沒有賽事。
# 20211215 沒有賽事。
# 20211216 沒有賽事。
# 20211217 沒有賽事。
# 20211218 完成。
# 20211219 完成。
# 20211220 沒有賽事。
# 20211221 沒有賽事。
# 20211222 沒有賽事。
# 20211223 沒有賽事。
# 20211224 沒有賽事。
# 20211225 完成。
# 20211226 完成。
# 20211227 沒有賽事。
# 20211228 完成。
# 20211229 沒有賽事。
# 20211230 沒有賽事。
# 20211231 沒有賽事。
# 20220101 沒有賽事。
# 20220102 沒有賽事。
# 20220103 沒有賽事。
# 20220104 沒有賽事。
# 20220105 完成。
# 20220106 沒有賽事。
# 20220107 沒有賽事。
# 20220108 完成。
# 20220109 完成。
# 20220110 完成。
# 20220111 沒有賽事。
# 20220112 沒有賽事。
# 20220113 沒有賽事。
# 20220114 沒有賽事。
# 20220115 完成。
# 20220116 完成。
# 20220117 沒有賽事。
# 20220118 沒有賽事。
# 20220119 沒有賽事。
# 20220120 沒有賽事。
# 20220121 沒有賽事。
# 20220122 完成。
# 20220123 完成。
# 20220124 沒有賽事。
# 20220125 沒有賽事。
# 20220126 沒有賽事。
# 20220127 沒有賽事。
# 20220128 沒有賽事。
# 20220129 完成。
# 20220130 完成。
# 20220131 沒有賽事。
# 20220201 沒有賽事。
# 20220202 沒有賽事。
# 20220203 沒有賽事。
# 20220204 沒有賽事。
# 20220205 完成。
# 20220206 完成。
# 20220207 沒有賽事。
# 20220208 沒有賽事。
# 20220209 沒有賽事。
# 20220210 沒有賽事。
# 20220211 沒有賽事。
# 20220212 完成。
# 20220213 完成。
# 20220214 沒有賽事。
# 20220215 沒有賽事。
# 20220216 沒有賽事。
# 20220217 沒有賽事。
# 20220218 沒有賽事。
# 20220219 完成。
# 20220220 完成。
# 20220221 沒有賽事。
# 20220222 沒有賽事。
# 20220223 沒有賽事。
# 20220224 沒有賽事。
# 20220225 沒有賽事。
# 20220226 完成。
# 20220227 完成。
# 20220228 沒有賽事。
# 20220301 沒有賽事。
# 20220302 沒有賽事。
# 20220303 沒有賽事。
# 20220304 沒有賽事。
# 20220305 完成。
# 20220306 完成。
# 20220307 沒有賽事。
# 20220308 沒有賽事。
# 20220309 沒有賽事。
# 20220310 沒有賽事。
# 20220311 沒有賽事。
# 20220312 完成。
# 20220313 完成。
# 20220314 沒有賽事。
# 20220315 沒有賽事。
# 20220316 沒有賽事。
# 20220317 沒有賽事。
# 20220318 沒有賽事。
# 20220319 完成。
# 20220320 完成。
# 20220321 完成。
# 20220322 沒有賽事。
# 20220323 沒有賽事。
# 20220324 沒有賽事。
# 20220325 沒有賽事。
# 20220326 完成。
# 20220327 完成。
# 20220328 沒有賽事。
# 20220329 沒有賽事。
# 20220330 沒有賽事。
# 20220331 沒有賽事。
# 20220401 沒有賽事。
# 20220402 完成。
# 20220403 完成。
# 20220404 沒有賽事。
# 20220405 沒有賽事。
# 20220406 沒有賽事。
# 20220407 沒有賽事。
# 20220408 沒有賽事。
# 20220409 完成。
# 20220410 完成。
# 20220411 沒有賽事。
# 20220412 沒有賽事。
# 20220413 沒有賽事。
# 20220414 沒有賽事。
# 20220415 沒有賽事。
# 20220416 完成。
# 20220417 完成。
# 20220418 沒有賽事。
# 20220419 沒有賽事。
# 20220420 沒有賽事。
# 20220421 沒有賽事。
# 20220422 沒有賽事。
# 20220423 完成。
# 20220424 完成。
# 20220425 沒有賽事。
# 20220426 沒有賽事。
# 20220427 沒有賽事。
# 20220428 沒有賽事。
# 20220429 沒有賽事。
# 20220430 完成。
# 20220501 完成。
# 20220502 沒有賽事。
# 20220503 沒有賽事。
# 20220504 沒有賽事。
# 20220505 沒有賽事。
# 20220506 沒有賽事。
# 20220507 完成。
# 20220508 完成。
# 20220509 沒有賽事。
# 20220510 沒有賽事。
# 20220511 沒有賽事。
# 20220512 沒有賽事。
# 20220513 沒有賽事。
# 20220514 完成。
# 20220515 完成。
# 20220516 沒有賽事。
# 20220517 沒有賽事。
# 20220518 沒有賽事。
# 20220519 沒有賽事。
# 20220520 沒有賽事。
# 20220521 完成。
# 20220522 完成。
# 20220523 沒有賽事。
# 20220524 沒有賽事。
# 20220525 沒有賽事。
# 20220526 沒有賽事。
# 20220527 沒有賽事。
# 20220528 完成。
# 20220529 完成。
# 20220530 沒有賽事。
# 20220531 沒有賽事。
# 20220601 沒有賽事。
# 20220602 沒有賽事。
# 20220603 沒有賽事。
# 20220604 完成。
# 20220605 完成。
# 20220606 沒有賽事。
# 20220607 沒有賽事。
# 20220608 沒有賽事。
# 20220609 沒有賽事。
# 20220610 沒有賽事。
# 20220611 完成。
# 20220612 完成。
# 20220613 沒有賽事。
# 20220614 沒有賽事。
# 20220615 沒有賽事。
# 20220616 沒有賽事。
# 20220617 沒有賽事。
# 20220618 完成。
# 20220619 完成。
# 20220620 沒有賽事。
# 20220621 沒有賽事。
# 20220622 沒有賽事。
# 20220623 沒有賽事。
# 20220624 沒有賽事。
# 20220625 完成。
# 20220626 完成。
# 20220627 沒有賽事。
# 20220628 沒有賽事。
# 20220629 沒有賽事。
# 20220630 沒有賽事。
# 20220701 沒有賽事。
# 20220702 完成。
# 20220703 完成。
# 20220704 沒有賽事。
# 20220705 沒有賽事。
# 20220706 沒有賽事。
# 20220707 沒有賽事。
# 20220708 沒有賽事。
# 20220709 完成。
# 20220710 完成。
# 20220711 沒有賽事。
# 20220712 沒有賽事。
# 20220713 沒有賽事。
# 20220714 沒有賽事。
# 20220715 沒有賽事。
# 20220716 完成。
# 20220717 完成。
# 20220718 沒有賽事。
# 20220719 沒有賽事。
# 20220720 沒有賽事。
# 20220721 沒有賽事。
# 20220722 沒有賽事。
# 20220723 完成。
# 20220724 完成。
# 20220725 沒有賽事。
# 20220726 沒有賽事。
# 20220727 沒有賽事。
# 20220728 沒有賽事。
# 20220729 沒有賽事。
# 20220730 完成。
# 20220731 完成。
# 20220801 沒有賽事。
# 20220802 沒有賽事。
# 20220803 沒有賽事。
# 20220804 沒有賽事。
# 20220805 沒有賽事。
# 20220806 完成。
# 20220807 完成。
# 20220808 沒有賽事。
# 20220809 沒有賽事。
# 20220810 沒有賽事。
# 20220811 沒有賽事。
# 20220812 沒有賽事。
# 20220813 完成。
# 20220814 完成。
# 20220815 沒有賽事。
# 20220816 沒有賽事。
# 20220817 沒有賽事。
# 20220818 沒有賽事。
# 20220819 沒有賽事。
# 20220820 完成。
# 20220821 完成。
# 20220822 沒有賽事。
# 20220823 沒有賽事。
# 20220824 沒有賽事。
# 20220825 沒有賽事。
# 20220826 沒有賽事。
# 20220827 完成。
# 20220828 完成。
# 20220829 沒有賽事。
# 20220830 沒有賽事。
# 20220831 沒有賽事。
# 20220901 沒有賽事。
# 20220902 沒有賽事。
# 20220903 完成。
# 20220904 完成。
# 20220905 沒有賽事。
# 20220906 沒有賽事。
# 20220907 沒有賽事。
# 20220908 沒有賽事。
# 20220909 沒有賽事。
# 20220910 完成。
# 20220911 完成。
# 20220912 沒有賽事。
# 20220913 沒有賽事。
# 20220914 沒有賽事。
# 20220915 沒有賽事。
# 20220916 沒有賽事。
# 20220917 完成。
# 20220918 完成。
# 20220919 完成。
# 20220920 沒有賽事。
# 20220921 沒有賽事。
# 20220922 沒有賽事。
# 20220923 沒有賽事。
# 20220924 完成。
# 20220925 完成。
# 20220926 沒有賽事。
# 20220927 沒有賽事。
# 20220928 沒有賽事。
# 20220929 沒有賽事。
# 20220930 沒有賽事。
# 20221001 完成。
# 20221002 完成。
# 20221003 沒有賽事。
# 20221004 沒有賽事。
# 20221005 沒有賽事。
# 20221006 沒有賽事。
# 20221007 沒有賽事。
# 20221008 完成。
# 20221009 完成。
# 20221010 完成。
# 20221011 沒有賽事。
# 20221012 沒有賽事。
# 20221013 沒有賽事。
# 20221014 沒有賽事。
# 20221015 完成。
# 20221016 完成。
# 20221017 沒有賽事。
# 20221018 沒有賽事。
# 20221019 沒有賽事。
# 20221020 沒有賽事。
# 20221021 沒有賽事。
# 20221022 完成。
# 20221023 完成。
# 20221024 沒有賽事。
# 20221025 沒有賽事。
# 20221026 沒有賽事。
# 20221027 沒有賽事。
# 20221028 沒有賽事。
# 20221029 完成。
# 20221030 完成。
# 20221031 沒有賽事。
# 20221101 沒有賽事。
# 20221102 沒有賽事。
# 20221103 沒有賽事。
# 20221104 沒有賽事。
# 20221105 完成。
# 20221106 完成。
# 20221107 沒有賽事。
# 20221108 沒有賽事。
# 20221109 沒有賽事。
# 20221110 沒有賽事。
# 20221111 沒有賽事。
# 20221112 完成。
# 20221113 完成。
# 20221114 沒有賽事。
# 20221115 沒有賽事。
# 20221116 沒有賽事。
# 20221117 沒有賽事。
# 20221118 沒有賽事。
# 20221119 完成。
# 20221120 完成。
# 20221121 沒有賽事。
# 20221122 沒有賽事。
# 20221123 沒有賽事。
# 20221124 沒有賽事。
# 20221125 沒有賽事。
# 20221126 完成。
# 20221127 完成。
# 20221128 沒有賽事。
# 20221129 沒有賽事。
# 20221130 沒有賽事。
# 20221201 沒有賽事。
# 20221202 沒有賽事。
# 20221203 完成。
# 20221204 完成。
# 20221205 沒有賽事。
# 20221206 沒有賽事。
# 20221207 沒有賽事。
# 20221208 沒有賽事。
# 20221209 沒有賽事。
# 20221210 完成。
# 20221211 完成。
# 20221212 沒有賽事。
# 20221213 沒有賽事。
# 20221214 沒有賽事。
# 20221215 沒有賽事。
# 20221216 沒有賽事。
# 20221217 完成。
# 20221218 完成。
# 20221219 沒有賽事。
# 20221220 沒有賽事。
# 20221221 沒有賽事。
# 20221222 沒有賽事。
# 20221223 沒有賽事。
# 20221224 完成。
# 20221225 完成。
# 20221226 沒有賽事。
# 20221227 沒有賽事。
# 20221228 完成。
# 20221229 沒有賽事。
# 20221230 沒有賽事。
# 20221231 沒有賽事。
# 20230101 沒有賽事。
# 20230102 沒有賽事。
# 20230103 沒有賽事。
# 20230104 沒有賽事。
# 20230105 完成。
# 20230106 沒有賽事。
# 20230107 完成。
# 20230108 完成。
# 20230109 完成。
# 20230110 沒有賽事。
# 20230111 沒有賽事。
# 20230112 沒有賽事。
# 20230113 沒有賽事。
# 20230114 完成。
# 20230115 完成。
# 20230116 沒有賽事。
# 20230117 沒有賽事。
# 20230118 沒有賽事。
# 20230119 沒有賽事。
# 20230120 沒有賽事。
# 20230121 完成。
# 20230122 完成。
# 20230123 沒有賽事。
# 20230124 沒有賽事。
# 20230125 沒有賽事。
# 20230126 沒有賽事。
# 20230127 沒有賽事。
# 20230128 完成。
# 20230129 完成。
# 20230130 沒有賽事。
# 20230131 沒有賽事。
# 20230201 沒有賽事。
# 20230202 沒有賽事。
# 20230203 沒有賽事。
# 20230204 完成。
# 20230205 完成。
# 20230206 沒有賽事。
# 20230207 沒有賽事。
# 20230208 沒有賽事。
# 20230209 沒有賽事。
# 20230210 沒有賽事。
# 20230211 完成。
# 20230212 完成。
# 20230213 沒有賽事。
# 20230214 沒有賽事。
# 20230215 沒有賽事。
# 20230216 沒有賽事。
# 20230217 沒有賽事。
# 20230218 完成。
# 20230219 完成。
# 20230220 沒有賽事。
# 20230221 沒有賽事。
# 20230222 沒有賽事。
# 20230223 沒有賽事。
# 20230224 沒有賽事。
# 20230225 完成。
# 20230226 完成。
# 20230227 沒有賽事。
# 20230228 沒有賽事。
# 20230301 沒有賽事。
# 20230302 沒有賽事。
# 20230303 沒有賽事。
# 20230304 完成。
# 20230305 完成。
# 20230306 沒有賽事。
# 20230307 沒有賽事。
# 20230308 沒有賽事。
# 20230309 沒有賽事。
# 20230310 沒有賽事。
# 20230311 完成。
# 20230312 完成。
# 20230313 沒有賽事。
# 20230314 沒有賽事。
# 20230315 沒有賽事。
# 20230316 沒有賽事。
# 20230317 沒有賽事。
# 20230318 完成。
# 20230319 完成。
# 20230320 沒有賽事。
# 20230321 沒有賽事。
# 20230322 沒有賽事。
# 20230323 沒有賽事。
# 20230324 沒有賽事。
# 20230325 完成。
# 20230326 完成。
# 20230327 沒有賽事。
# 20230328 沒有賽事。
# 20230329 沒有賽事。
# 20230330 沒有賽事。
# 20230331 沒有賽事。
# 20230401 完成。
# 20230402 完成。
# 20230403 沒有賽事。
# 20230404 沒有賽事。
# 20230405 沒有賽事。
# 20230406 沒有賽事。
# 20230407 沒有賽事。
# 20230408 完成。
# 20230409 完成。
# 20230410 沒有賽事。
# 20230411 沒有賽事。
# 20230412 沒有賽事。
# 20230413 沒有賽事。
# 20230414 沒有賽事。
# 20230415 完成。
# 20230416 完成。
# 20230417 沒有賽事。
# 20230418 沒有賽事。
# 20230419 沒有賽事。
# 20230420 沒有賽事。
# 20230421 沒有賽事。
# 20230422 完成。
# 20230423 完成。
# 20230424 沒有賽事。
# 20230425 沒有賽事。
# 20230426 沒有賽事。
# 20230427 沒有賽事。
# 20230428 沒有賽事。
# 20230429 完成。
# 20230430 完成。
# 20230501 沒有賽事。
# 20230502 沒有賽事。
# 20230503 沒有賽事。
# 20230504 沒有賽事。
# 20230505 沒有賽事。
# 20230506 完成。
# 20230507 完成。
# 20230508 沒有賽事。
# 20230509 沒有賽事。
# 20230510 沒有賽事。
# 20230511 沒有賽事。
# 20230512 沒有賽事。
# 20230513 完成。
# 20230514 完成。
# 20230515 沒有賽事。
# 20230516 沒有賽事。
# 20230517 沒有賽事。
# 20230518 沒有賽事。
# 20230519 沒有賽事。
# 20230520 完成。
# 20230521 完成。
# 20230522 沒有賽事。
# 20230523 沒有賽事。
# 20230524 沒有賽事。
# 20230525 沒有賽事。
# 20230526 沒有賽事。
# 20230527 完成。
# 20230528 完成。
# 20230529 沒有賽事。
# 20230530 沒有賽事。
# 20230531 沒有賽事。
# 20230601 沒有賽事。
# 20230602 沒有賽事。
# 20230603 完成。
# 20230604 完成。
# 20230605 沒有賽事。
# 20230606 沒有賽事。
# 20230607 沒有賽事。
# 20230608 沒有賽事。
# 20230609 沒有賽事。
# 20230610 完成。
# 20230611 完成。
# 20230612 沒有賽事。
# 20230613 沒有賽事。
# 20230614 沒有賽事。
# 20230615 沒有賽事。
# 20230616 沒有賽事。
# 20230617 完成。
# 20230618 完成。
# 20230619 沒有賽事。
# 20230620 沒有賽事。
# 20230621 沒有賽事。
# 20230622 沒有賽事。
# 20230623 沒有賽事。
# 20230624 完成。
# 20230625 完成。
# 20230626 沒有賽事。
# 20230627 沒有賽事。
# 20230628 沒有賽事。
# 20230629 沒有賽事。
# 20230630 沒有賽事。
# 20230701 完成。
# 20230702 完成。
# 20230703 沒有賽事。
# 20230704 沒有賽事。
# 20230705 沒有賽事。
# 20230706 沒有賽事。
# 20230707 沒有賽事。
# 20230708 完成。
# 20230709 完成。
# 20230710 沒有賽事。
# 20230711 沒有賽事。
# 20230712 沒有賽事。
# 20230713 沒有賽事。
# 20230714 沒有賽事。
# 20230715 完成。
# 20230716 完成。
# 20230717 沒有賽事。
# 20230718 沒有賽事。
# 20230719 沒有賽事。
# 20230720 沒有賽事。
# 20230721 沒有賽事。
# 20230722 完成。
# 20230723 完成。
# 20230724 沒有賽事。
# 20230725 沒有賽事。
# 20230726 沒有賽事。
# 20230727 沒有賽事。
# 20230728 沒有賽事。
# 20230729 完成。
# 20230730 完成。
# 20230731 沒有賽事。
# 20230801 沒有賽事。
# 20230802 沒有賽事。
# 20230803 沒有賽事。
# 20230804 沒有賽事。
# 20230805 完成。
# 20230806 完成。
# 20230807 沒有賽事。
# 20230808 沒有賽事。
# 20230809 沒有賽事。
# 20230810 沒有賽事。
# 20230811 沒有賽事。
# 20230812 完成。
# 20230813 完成。
# 20230814 沒有賽事。
# 20230815 沒有賽事。
# 20230816 沒有賽事。
# 20230817 沒有賽事。
# 20230818 沒有賽事。
# 20230819 完成。
# 20230820 完成。
# 20230821 沒有賽事。
# 20230822 沒有賽事。
# 20230823 沒有賽事。
# 20230824 沒有賽事。
# 20230825 沒有賽事。
# 20230826 完成。
# 20230827 完成。
# 20230828 沒有賽事。
# 20230829 沒有賽事。
# 20230830 沒有賽事。
# 20230831 沒有賽事。
# 20230901 沒有賽事。
# 20230902 完成。
# 20230903 完成。
# 20230904 沒有賽事。
# 20230905 沒有賽事。
# 20230906 沒有賽事。
# 20230907 沒有賽事。
# 20230908 沒有賽事。
# 20230909 沒有賽事。
# 20230910 沒有賽事。
# 20230911 沒有賽事。
# 20230912 沒有賽事。
# 20230913 沒有賽事。
# 20230914 沒有賽事。
# 20230915 沒有賽事。
# 20230916 沒有賽事。
# 20230917 沒有賽事。
# 20230918 沒有賽事。
# 20230919 沒有賽事。
# 20230920 沒有賽事。
# 20230921 沒有賽事。
# 20230922 沒有賽事。
# 20230923 沒有賽事。
# 20230924 沒有賽事。
# 20230925 沒有賽事。
# 20230926 沒有賽事。
# 20230927 沒有賽事。
# 20230928 沒有賽事。
# 20230929 沒有賽事。
# 20230930 沒有賽事。
# 20231001 沒有賽事。

# %%
import pandas as pd
df = pd.read_csv('2020-2023賽馬賽事_1.csv')
print(df.isna().sum())

# missing_race_place_dates = df[df['地點'].isna()]['賽事時間']
# print(missing_race_place_dates)

missing_race_place_dates = df[df['地點'].isna()]['賽事時間'].unique()
print("缺失地點的日期：")
if len(missing_race_place_dates) > 0:
    for date in missing_race_place_dates:
        print(date)
else:
    print("nothing")
# Out:
# 賽事時間       0
# 地點         0
# 場名         0
# 場次         0
# 距離         0
# 天氣         0
# 名次         0
# 馬名         0
# 性別年紀       0
# 馬重量        0
# 騎手         0
# 重量         0
# 抵達時間    1400
# 單柱賠率       0
# 獎金         0
# dtype: int64
# 缺失地點的日期：
# nothing

# %%
import pandas as pd

# 读取CSV文件
df = pd.read_csv('2020-2023賽馬賽事.csv')

# 定义特定的赛事时间和填充值
fill_value = "中山"

# 使用 loc 选择特定赛事时间的行，并填充地点列的缺失值为"中山"
df.loc[(df['賽事時間'] == 20200329) & (df['地點'].isna()), '地點'] ="中山"
df.loc[(df['賽事時間'] == 20200331) & (df['地點'].isna()), '地點'] ="中山"
df['獎金'].fillna(0, inplace=True)
# 选择指定日期的前16筆資料
filtered_data1 = df[df['賽事時間'] == 20200329].head(10)
filtered_data2 = df[df['賽事時間'] == 20200331].head(10)
# 打印出指定日期的前16筆資料
print(filtered_data1)
print(filtered_data2)

# 保存修改後的DataFrame到新的CSV文件
df.to_csv('2020-2023賽馬賽事_1.csv', index=False, encoding='utf-8-sig')
# Out:
#            賽事時間  地點     場名   場次        距離        天氣  名次         馬名 性別年紀  \
# 12114  20200329  中山  3歳未勝利  1 R  ダ右1800m    天候 : 雨    1    ピュアブレンド   牝3
# 12115  20200329  中山  3歳未勝利  1 R  ダ右1800m    天候 : 雨    2   ジュールサイクル   牝3
# 12116  20200329  中山  3歳未勝利  1 R  ダ右1800m    天候 : 雨    3   ストリートピアノ   牝3
# 12117  20200329  中山  3歳未勝利  1 R  ダ右1800m    天候 : 雨    4  プレシャススパート   牝3
# 12118  20200329  中山  3歳未勝利  1 R  ダ右1800m    天候 : 雨    5    ルージュキッス   牝3
# 12119  20200329  中山  3歳未勝利  1 R  ダ右1800m    天候 : 雨    6     ラブキーセキ   牝3
# 12120  20200329  中山  3歳未勝利  1 R  ダ右1800m    天候 : 雨    7    キアナポラリス   牝3
# 12121  20200329  中山  3歳未勝利  1 R  ダ右1800m    天候 : 雨    8    カイエトゥール   牝3
# 12122  20200329  中山  3歳未勝利  1 R  ダ右1800m    天候 : 雨    9     カゼニノッテ   牝3
# 12123  20200329  中山  3歳未勝利  1 R  ダ右1800m    天候 : 雨   10    フクノフェザン   牝3
#
#             馬重量    騎手    重量    抵達時間   單柱賠率     獎金
# 12114    486(0)  木幡育也  52.0  1:55.5    4.5  510.0
# 12115    448(0)  内田博幸  54.0  1:56.0    5.1  200.0
# 12116   458(-4)   吉田豊  54.0  1:56.3    4.7  130.0
# 12117   508(+4)  的場勇人  54.0  1:57.5   25.3   77.0
# 12118   436(-2)  宮崎北斗  54.0  1:57.6   62.4   51.0
# 12119   412(-2)  小林凌大  51.0  1:58.1  105.3      0
# 12120   436(+2)  野中悠太  54.0  1:58.4    9.5      0
# 12121    480(0)  丹内祐次  54.0  1:58.7   19.6      0
# 12122  448(+10)  大庭和弥  54.0  1:58.7  164.8      0
# 12123    478(0)  木幡初也  54.0  1:58.8  121.6      0
#            賽事時間  地點     場名   場次        距離        天氣  名次         馬名 性別年紀  \
# 12485  20200331  中山  3歳未勝利  3 R  ダ右1800m    天候 : 曇    1   フォーチュネイト   牡3
# 12486  20200331  中山  3歳未勝利  3 R  ダ右1800m    天候 : 曇    2     サンビュート   セ3
# 12487  20200331  中山  3歳未勝利  3 R  ダ右1800m    天候 : 曇    3  グラスデスティーノ   牡3
# 12488  20200331  中山  3歳未勝利  3 R  ダ右1800m    天候 : 曇    4  ワンモアエフォート   牡3
# 12489  20200331  中山  3歳未勝利  3 R  ダ右1800m    天候 : 曇    5  ネヴァタップアウト   牡3
# 12490  20200331  中山  3歳未勝利  3 R  ダ右1800m    天候 : 曇    6     グランクロワ   セ3
# 12491  20200331  中山  3歳未勝利  3 R  ダ右1800m    天候 : 曇    7   カガジャスティス   牡3
# 12492  20200331  中山  3歳未勝利  3 R  ダ右1800m    天候 : 曇    8  セイカアーナンダイ   牡3
# 12493  20200331  中山  3歳未勝利  3 R  ダ右1800m    天候 : 曇    9  トミケンアラバール   牡3
# 12494  20200331  中山  3歳未勝利  3 R  ダ右1800m    天候 : 曇   10  ペイシャジャングル   牡3
#
#             馬重量    騎手    重量    抵達時間   單柱賠率     獎金
# 12485   456(-4)  武士沢友  56.0  1:54.7   39.4  510.0
# 12486   484(-8)  北村宏司  56.0  1:54.8    5.1  200.0
# 12487   478(-2)  木幡巧也  56.0  1:55.0    8.4  130.0
# 12488   480(-8)  横山和生  56.0  1:55.6    3.6   77.0
# 12489  518(+10)  津村明秀  56.0  1:55.8    4.5   51.0
# 12490   450(-2)   石橋脩  56.0  1:57.0  156.3      0
# 12491   508(-6)  大野拓弥  56.0  1:57.1   12.6      0
# 12492   466(+4)  石川裕紀  56.0  1:57.2  190.0      0
# 12493  514(-10)   原優介  53.0  1:57.5   44.9      0
# 12494  474(-12)  山田敬士  53.0  1:57.7   85.4      0

# %%
import pandas as pd

# 读取CSV文件
df = pd.read_csv('2020-2023賽馬賽事.csv')

# 定义特定的赛事时间
specific_date = 20200329  # 修改为您所需的赛事时间

# 选择指定日期的前16筆資料
filtered_data = df[df['賽事時間'] == specific_date].head(16)

# 打印出指定日期的前16筆資料
print(filtered_data)
# Out:
#            賽事時間   地點     場名   場次        距離        天氣  名次         馬名 性別年紀  \
# 12114  20200329  NaN  3歳未勝利  1 R  ダ右1800m    天候 : 雨    1    ピュアブレンド   牝3
# 12115  20200329  NaN  3歳未勝利  1 R  ダ右1800m    天候 : 雨    2   ジュールサイクル   牝3
# 12116  20200329  NaN  3歳未勝利  1 R  ダ右1800m    天候 : 雨    3   ストリートピアノ   牝3
# 12117  20200329  NaN  3歳未勝利  1 R  ダ右1800m    天候 : 雨    4  プレシャススパート   牝3
# 12118  20200329  NaN  3歳未勝利  1 R  ダ右1800m    天候 : 雨    5    ルージュキッス   牝3
# 12119  20200329  NaN  3歳未勝利  1 R  ダ右1800m    天候 : 雨    6     ラブキーセキ   牝3
# 12120  20200329  NaN  3歳未勝利  1 R  ダ右1800m    天候 : 雨    7    キアナポラリス   牝3
# 12121  20200329  NaN  3歳未勝利  1 R  ダ右1800m    天候 : 雨    8    カイエトゥール   牝3
# 12122  20200329  NaN  3歳未勝利  1 R  ダ右1800m    天候 : 雨    9     カゼニノッテ   牝3
# 12123  20200329  NaN  3歳未勝利  1 R  ダ右1800m    天候 : 雨   10    フクノフェザン   牝3
# 12124  20200329  NaN  3歳未勝利  1 R  ダ右1800m    天候 : 雨   11  アオイサンゴショウ   牝3
# 12125  20200329  NaN  3歳未勝利  1 R  ダ右1800m    天候 : 雨   12  サフランハーモニー   牝3
# 12126  20200329  NaN  3歳未勝利  1 R  ダ右1800m    天候 : 雨   13   ゼンダンスネーク   牝3
# 12127  20200329  NaN  3歳未勝利  1 R  ダ右1800m    天候 : 雨   14   クイックスタディ   牝3
# 12128  20200329  NaN  3歳未勝利  1 R  ダ右1800m    天候 : 雨   15  ソフィスティケイト   牝3
# 12129  20200329  NaN  3歳未勝利  1 R  ダ右1800m    天候 : 雨   16  ワンダーマンキアオ   牝3
#
#             馬重量    騎手    重量    抵達時間   單柱賠率     獎金
# 12114    486(0)  木幡育也  52.0  1:55.5    4.5  510.0
# 12115    448(0)  内田博幸  54.0  1:56.0    5.1  200.0
# 12116   458(-4)   吉田豊  54.0  1:56.3    4.7  130.0
# 12117   508(+4)  的場勇人  54.0  1:57.5   25.3   77.0
# 12118   436(-2)  宮崎北斗  54.0  1:57.6   62.4   51.0
# 12119   412(-2)  小林凌大  51.0  1:58.1  105.3    NaN
# 12120   436(+2)  野中悠太  54.0  1:58.4    9.5    NaN
# 12121    480(0)  丹内祐次  54.0  1:58.7   19.6    NaN
# 12122  448(+10)  大庭和弥  54.0  1:58.7  164.8    NaN
# 12123    478(0)  木幡初也  54.0  1:58.8  121.6    NaN
# 12124    430(0)   武藤雅  54.0  1:58.8   17.3    NaN
# 12125   460(+2)   黛弘人  54.0  1:59.2   10.1    NaN
# 12126   454(+4)  横山和生  54.0  1:59.8   60.5    NaN
# 12127    476(0)  津村明秀  54.0  1:59.9   14.9    NaN
# 12128   448(+4)  藤田菜七  52.0  2:01.4    7.9    NaN
# 12129    454(0)  大野拓弥  54.0  2:09.4   47.0    NaN

# %%
# Out:
# Collecting Flask
#   Downloading flask-2.3.3-py3-none-any.whl (96 kB)
#      ---------------------------------------- 96.1/96.1 kB 1.4 MB/s eta 0:00:00
# Collecting Werkzeug>=2.3.7
#   Downloading werkzeug-2.3.7-py3-none-any.whl (242 kB)
#      -------------------------------------- 242.2/242.2 kB 3.7 MB/s eta 0:00:00
# Collecting Jinja2>=3.1.2
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      -------------------------------------- 133.1/133.1 kB 7.7 MB/s eta 0:00:00
# Collecting itsdangerous>=2.1.2
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting click>=8.1.3
#   Downloading click-8.1.7-py3-none-any.whl (97 kB)
#      ---------------------------------------- 97.9/97.9 kB 5.5 MB/s eta 0:00:00
# Collecting blinker>=1.6.2
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python311\site-packages (from click>=8.1.3->Flask) (0.4.6)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.3-cp311-cp311-win_amd64.whl (17 kB)
# Installing collected packages: MarkupSafe, itsdangerous, click, blinker, Werkzeug, Jinja2, Flask
# Successfully installed Flask-2.3.3 Jinja2-3.1.2 MarkupSafe-2.1.3 Werkzeug-2.3.7 blinker-1.6.2 click-8.1.7 itsdangerous-2.1.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script flask.exe is installed in 'c:\Users\User\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Out:
# Collecting flask-login
#   Downloading Flask_Login-0.6.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from flask-login) (2.3.3)
# Requirement already satisfied: Werkzeug>=1.0.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from flask-login) (2.3.7)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from Flask>=1.0.4->flask-login) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from Flask>=1.0.4->flask-login) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from Flask>=1.0.4->flask-login) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from Flask>=1.0.4->flask-login) (1.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from Werkzeug>=1.0.1->flask-login) (2.1.3)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python311\site-packages (from click>=8.1.3->Flask>=1.0.4->flask-login) (0.4.6)
# Installing collected packages: flask-login
# Successfully installed flask-login-0.6.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
